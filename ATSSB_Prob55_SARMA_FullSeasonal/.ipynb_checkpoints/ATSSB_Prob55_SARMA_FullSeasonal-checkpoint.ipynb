# %% [markdown]
# # ATSSB_Prob55_SARMA_FullSeasonal

# %%
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA
import math

from PythonTsa.plot_acf_pacf import acf_pacf_fig
from PythonTsa.LjungBoxtest import plot_LB_pvalue
from PythonTsa.ModResidDiag import plot_ResidDiag
from PythonTsa.datadir import getdtapath

plt.rcParams.update({
    "figure.figsize": (10,6),
    "figure.facecolor": "none",
    "axes.facecolor": "none",
    "savefig.transparent": True,
    "axes.grid": False,
    "axes.spines.top": False,
    "axes.spines.right": False,
    "legend.frameon": False
})

# %%
phi=np.r_[0.2]; theta=np.r_[-0.5]
Phi=np.r_[-0.3]; Theta=np.r_[0.4]; sigma2=4
params=np.r_[phi,theta,Phi,Theta,sigma2]

sim=sm.tsa.SARIMAX([0],order=(1,0,1),seasonal_order=(1,0,1,4)).simulate(params,3000)
sim=pd.Series(sim)

sim.plot(label='Simulated')
plt.legend(loc='upper center', bbox_to_anchor=(0.5,-0.15))
plt.savefig("series.png",dpi=300); plt.savefig("series.pdf"); plt.show()

acf_pacf_fig(sim,both=True,lag=24)
plt.savefig("acf_pacf.png",dpi=300); plt.savefig("acf_pacf.pdf"); plt.show()

m=sm.tsa.SARIMAX(sim,order=(1,0,1),seasonal_order=(1,0,1,4)).fit(disp=False)
print(m.summary())

plot_ResidDiag(m.resid,4,30,30)
plt.savefig("diagnostics.png",dpi=300); plt.savefig("diagnostics.pdf"); plt.show()
# Out:
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                                 y   No. Observations:                 3000
# Model:             SARIMAX(1, 0, 1)x(1, 0, 1, 4)   Log Likelihood               -6300.953
# Date:                           Wed, 18 Feb 2026   AIC                          12611.907
# Time:                                   13:22:37   BIC                          12641.938
# Sample:                                        0   HQIC                         12622.709
#                                           - 3000
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0856      0.057      1.510      0.131      -0.026       0.197
# ma.L1         -0.3984      0.053     -7.558      0.000      -0.502      -0.295
# ar.S.L4       -0.1515      0.166     -0.914      0.361      -0.476       0.173
# ma.S.L4        0.2557      0.162      1.579      0.114      -0.062       0.573
# sigma2         3.9067      0.098     39.693      0.000       3.714       4.100
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 2.10
# Prob(Q):                              0.99   Prob(JB):                         0.35
# Heteroskedasticity (H):               0.98   Skew:                            -0.04
# Prob(H) (two-sided):                  0.81   Kurtosis:                         3.11
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
